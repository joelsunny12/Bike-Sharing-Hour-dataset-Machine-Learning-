# %%
import math

import pandas as pd

import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn import metrics
import scipy.stats as stats

import statsmodels.api as sm
import numpy as np

from sklearn import preprocessing

# %%
df = pd.read_csv('../Downloads/bike-sharing-hour.csv', index_col=0)
df
# Out:
#              dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# instant
# 1        2011-01-01       1   0     1   0        0        6           0
# 2        2011-01-01       1   0     1   1        0        6           0
# 3        2011-01-01       1   0     1   2        0        6           0
# 4        2011-01-01       1   0     1   3        0        6           0
# 5        2011-01-01       1   0     1   4        0        6           0
# ...             ...     ...  ..   ...  ..      ...      ...         ...
# 17375    2012-12-31       1   1    12  19        0        1           1
# 17376    2012-12-31       1   1    12  20        0        1           1
# 17377    2012-12-31       1   1    12  21        0        1           1
# 17378    2012-12-31       1   1    12  22        0        1           1
# 17379    2012-12-31       1   1    12  23        0        1           1
#
#          weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# instant
# 1                 1  0.24  0.2879  0.81     0.0000       3          13   16
# 2                 1  0.22  0.2727  0.80     0.0000       8          32   40
# 3                 1  0.22  0.2727  0.80     0.0000       5          27   32
# 4                 1  0.24  0.2879  0.75     0.0000       3          10   13
# 5                 1  0.24  0.2879  0.75     0.0000       0           1    1
# ...             ...   ...     ...   ...        ...     ...         ...  ...
# 17375             2  0.26  0.2576  0.60     0.1642      11         108  119
# 17376             2  0.26  0.2576  0.60     0.1642       8          81   89
# 17377             1  0.26  0.2576  0.60     0.1642       7          83   90
# 17378             1  0.26  0.2727  0.56     0.1343      13          48   61
# 17379             1  0.26  0.2727  0.65     0.1343      12          37   49
#
# [17379 rows x 16 columns]

# %%
df.columns
# Out:
# Index(['dteday', 'season', 'yr', 'mnth', 'hr', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
#        'casual', 'registered', 'cnt'],
#       dtype='object')

# %%
df = pd.read_csv('../Downloads/bike-sharing-hour.csv', index_col=0)
df = df.drop('dteday', axis=1)
independent_variables = df.drop('cnt', axis=1)
x = independent_variables.values
y = df['cnt'].values

lr = LinearRegression(fit_intercept = True)
lr.fit(x, y)
y_pred = lr.predict(x)

# %%
print('Coefficients = ', lr.coef_)
# Out:
# Coefficients =  [-4.83688023e-14  8.98927921e-14  1.49966435e-14 -8.43734522e-15
#  -1.53136495e-15 -2.77812901e-15  1.94927022e-14 -1.18822928e-14
#  -1.19607713e-13 -2.64368889e-13  5.92372913e-14 -3.40541410e-14
#   1.00000000e+00  1.00000000e+00]

# %%
print('Intercept = ', lr.intercept_)
# Out:
# Intercept =  3.410605131648481e-13

# %%
print('R^2 = ', lr.score(x, y))
# Out:
# R^2 =  1.0

# %%
print('Root MSE = ', math.sqrt(metrics.mean_squared_error(y, y_pred)))
# Out:
# Root MSE =  1.683500083800179e-13

# %%
x = independent_variables
y = df['cnt']

x2 = sm.add_constant(x)
ols = sm.OLS(y, x2)
est = ols.fit()

est.summary()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 2.149e+31
# Date:                Thu, 09 Jun 2022   Prob (F-statistic):               0.00
# Time:                        10:59:56   Log-Likelihood:             4.4997e+05
# No. Observations:               17379   AIC:                        -8.999e+05
# Df Residuals:                   17364   BIC:                        -8.998e+05
# Df Model:                          14
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1.961e-12   6.91e-14    -28.381      0.000    -2.1e-12   -1.83e-12
# season     -1.386e-13   1.77e-14     -7.810      0.000   -1.73e-13   -1.04e-13
# yr          2.437e-12   2.19e-14    111.378      0.000    2.39e-12    2.48e-12
# mnth        2.025e-13   5.51e-15     36.743      0.000    1.92e-13    2.13e-13
# hr         -1.743e-14    1.7e-15    -10.256      0.000   -2.08e-14   -1.41e-14
# holiday     2.132e-14   6.51e-14      0.327      0.743   -1.06e-13    1.49e-13
# weekday     -2.22e-15   5.26e-15     -0.422      0.673   -1.25e-14    8.09e-15
# workingday -4.641e-14   2.66e-14     -1.743      0.081   -9.86e-14    5.78e-15
# weathersit -1.243e-14   1.85e-14     -0.671      0.502   -4.88e-14    2.39e-14
# temp       -3.411e-13   3.59e-13     -0.949      0.343   -1.05e-12    3.64e-13
# atemp       4.547e-13   4.04e-13      1.126      0.260   -3.37e-13    1.25e-12
# hum        -7.283e-14      7e-14     -1.041      0.298    -2.1e-13    6.43e-14
# windspeed   1.421e-14   9.36e-14      0.152      0.879   -1.69e-13    1.98e-13
# casual         1.0000   3.13e-16   3.19e+15      0.000       1.000       1.000
# registered     1.0000   9.23e-17   1.08e+16      0.000       1.000       1.000
# ==============================================================================
# Omnibus:                     6516.696   Durbin-Watson:                   0.039
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              915.596
# Skew:                          -0.150   Prob(JB):                    1.52e-199
# Kurtosis:                       1.916   Cond. No.                     1.14e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.14e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
#The model after normalisation has an R^2 value of 1.000
#F-Statistic is 2.149e+31
#RMSE = 1.683500083800179e-13
